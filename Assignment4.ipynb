# %% [markdown]
# <a href="https://colab.research.google.com/github/karthik-garlapally/Machine_Lerning/blob/main/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment 4

# %% [markdown]
# #Write a Python program to predict house prices using the California Housing Dataset by implementing a Linear Regression model. Program should perform the following tasks:
#
# 1.Load the California Housing dataset using fetch_california_housing().
#
# 2.Convert the dataset into a Pandas DataFrame.
#
# 3.Separate the input features (X) and target variable (HouseValue).
#
# 4.Normalize the input features using the MinMaxScaler.
#
# 5.Split the dataset into 80% training and 20% testing sets.
#
# 6.Train a Linear Regression model using the training data.
#
# 7.Display the intercept and coefficients of the trained model.
#
# 8.Predict the house prices for the test dataset.
#
# 9.Evaluate the performance of the model using the following metrics:
# Mean Absolute Error (MAE)
# Mean Squared Error (MSE)
# Root Mean Squared Error (RMSE)
# R² Score
#
# 10.Display the predicted house prices and the evaluation metrics

# %% [markdown]
# 1. Load the California Housing Dataset

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
#      <input type="file" id="files-432b67fb-e6f9-4c1f-844b-2883df8abe0f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-432b67fb-e6f9-4c1f-844b-2883df8abe0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 2. Convert the dataset into a Pandas DataFrame

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# #READING THE DATASET

# %% [markdown]
# 3.Display first 5 rows

# %%
housing = fetch_california_housing()
df = pd.DataFrame(
    housing.data,
    columns=housing.feature_names
)
df["HouseValue"] = housing.target
print(df.head())
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  HouseValue
# 0    -122.23       4.526
# 1    -122.22       3.585
# 2    -122.24       3.521
# 3    -122.25       3.413
# 4    -122.25       3.422

# %% [markdown]
# #PRE-PROCESSING THE DATA

# %% [markdown]
# 4.HANDLING MISSING VALUES

# %%
print(df.isnull().sum())
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# HouseValue    0
# dtype: int64

# %% [markdown]
# 5.Separate the input features (X) and target variable (HouseValue).

# %%
X = df.drop("HouseValue", axis=1)
y = df["HouseValue"]

# %% [markdown]
# 6.NORMALIZING THE DATA

# %%
normalizer = MinMaxScaler()
X_normalized = normalizer.fit_transform(X)
print(X_normalized[:5])
# Out:
# [[0.53966842 0.78431373 0.0435123  0.02046866 0.00894083 0.00149943
#   0.5674814  0.21115538]
#  [0.53802706 0.39215686 0.03822395 0.01892926 0.0672104  0.00114074
#   0.565356   0.21215139]
#  [0.46602805 1.         0.05275646 0.02194011 0.01381765 0.00169796
#   0.5642933  0.21015936]
#  [0.35469856 1.         0.03524099 0.02192864 0.01555537 0.0014933
#   0.5642933  0.20916335]
#  [0.23077613 1.         0.03853386 0.02216644 0.01575156 0.00119838
#   0.5642933  0.20916335]]

# %% [markdown]
# #TRAINING AND TESTING

# %% [markdown]
# 7. Split the dataset into 80% training and 20% testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_normalized,
    y,
    test_size=0.2,
    random_state=42
)
print(X_train.shape)
print(X_test.shape)
# Out:
# (16512, 8)
# (4128, 8)

# %% [markdown]
# #APPLYING LINEAR REGRESSION

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 8.READING THE INTERCEPT VALUE AND COEFFCIENT/ SLOPE.

# %%
print("Intercept:", model.intercept_)
print("Coefficients:")
for feature, coef in zip(X.columns, model.coef_):
    print(feature, ":", coef)
# Out:
# Intercept: 3.6365398986163004
# Coefficients:
# MedInc : 6.505875925134837
# HouseAge : 0.4959371334131195
# AveRooms : -17.396352947731362
# AveBedrms : 26.41808818914954
# Population : -0.07241483267890166
# AveOccup : -4.381948021589269
# Latitude : -3.9502472987964556
# Longitude : -4.354428972238426

# %% [markdown]
# #PREDICT ON TEST DATA

# %%
y_pred = model.predict(X_test)
print(y_pred[:10])
# Out:
# [0.71912284 1.76401657 2.70965883 2.83892593 2.60465725 2.01175367
#  2.64550005 2.16875532 2.74074644 3.91561473]

# %% [markdown]
# #EVALUATION METRICS

# %% [markdown]
# 1.MEAN ABSOLUTE ERROR

# %%
mae = mean_absolute_error(y_test, y_pred)
print("MAE =", mae)
# Out:
# MAE = 0.5332001304956556

# %% [markdown]
# 2.MEAN SQUARED ERROR

# %%
mse = mean_squared_error(y_test, y_pred)
print("MSE =", mse)
# Out:
# MSE = 0.555891598695244

# %% [markdown]
# 3.ROOT MEAN SQUARED ERROR

# %%
rmse = np.sqrt(mse)
print("RMSE =", rmse)
# Out:
# RMSE = 0.7455813830127761

# %% [markdown]
# $R^2$ SCORE

# %%
r2 = r2_score(y_test, y_pred)
print("R2 Score =", r2)
# Out:
# R2 Score = 0.5757877060324511
